# %% [markdown]
# # EE219 Project 2

# %% [markdown]
# # Problem 1

# %%
from sklearn.datasets import fetch_20newsgroups
from sklearn.feature_extraction import text
from sklearn.feature_extraction.text import TfidfTransformer, CountVectorizer
from nltk.corpus import stopwords
import re

comp_tech_subclasses = ['comp.graphics', 
                        'comp.os.ms-windows.misc', 
                        'comp.sys.ibm.pc.hardware', 
                        'comp.sys.mac.hardware']
                        
rec_act_subclasses = ['rec.autos', 
                      'rec.motorcycles', 
                      'rec.sport.baseball', 
                      'rec.sport.hockey']
  
dataset = fetch_20newsgroups(subset='all',
                             categories=comp_tech_subclasses+rec_act_subclasses,
                             shuffle=True,
                             random_state=42,
                             remove=('headers', 'footers', 'quotes'))

stop_words = text.ENGLISH_STOP_WORDS

vect_all = CountVectorizer(analyzer = 'word', stop_words = stop_words, min_df = 3)
counts_all = vect_all.fit_transform(dataset.data)
TFxIDF_transformer = TfidfTransformer()
X = TFxIDF_transformer.fit_transform(counts_all)

print("The dimension of TF-IDF Vector with min_df=3 is",X.shape)
# Out:
# The dimension of TF-IDF Vector with min_df=3 is (7882, 18469)

# %% [markdown]
# # problem 2

# %%
new_target = (dataset.target[:]<4)*1

# %%
from sklearn.cluster import KMeans
from sklearn import metrics

km = KMeans(n_clusters=2, init='k-means++', max_iter=500, n_init=5)
km.fit(X)

print ('Homogeneity:', metrics.homogeneity_score(new_target, km.labels_))
print ('Completeness:', metrics.completeness_score(new_target, km.labels_))
print ('V-measure:', metrics.v_measure_score(new_target, km.labels_))
print ('Adjusted Rand Score:', metrics.adjusted_rand_score(new_target, km.labels_))
print ('Adjusted Mutual Info Score:', metrics.adjusted_mutual_info_score(new_target, km.labels_))
print ('The contingency matrix:\n',metrics.confusion_matrix(new_target, km.labels_),'\n'*2)
# Out:
# Homogeneity: 0.417158736808
# Completeness: 0.455663349287
# V-measure: 0.435561726098
# Adjusted Rand Score: 0.424195811295
# Adjusted Mutual Info Score: 0.417105375768
# The contingency matrix:
#  [[3941   38]
#  [1336 2567]]

# %% [markdown]
# # probem 3

# %%
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.decomposition import TruncatedSVD
from sklearn.decomposition import NMF
from scipy.sparse.linalg import svds
from sklearn.preprocessing import Normalizer
from sklearn.pipeline import make_pipeline
from math import log
import matplotlib.pyplot as plt

# %%
svd = TruncatedSVD(n_components = 1000, n_iter = 13,random_state = 42)
svd.fit(X)
variance = svd.explained_variance_ratio_
va_sum = [(sum(variance[:t])) for t in range(1,1001)]
plt.plot(range(1,1001), va_sum)
plt.ylabel('Variance Ratio', fontsize = 20)
plt.xlabel('Index', fontsize = 20)
plt.show()

# %%
def k_means(X_reduced, labels):

    km = KMeans(n_clusters=2, init='k-means++', max_iter=500, n_init=5)
    km.fit(X_reduced)
    
    homo.append(metrics.homogeneity_score(new_target, km.labels_))
    complet.append(metrics.completeness_score(new_target, km.labels_))
    vmeasure.append(metrics.v_measure_score(new_target, km.labels_))
    rands.append(metrics.adjusted_rand_score(new_target, km.labels_))
    mutual.append(metrics.adjusted_mutual_info_score(new_target, km.labels_))
      
    print ('Homogeneity:', metrics.homogeneity_score(new_target, km.labels_))
    print ('Completeness:', metrics.completeness_score(new_target, km.labels_))
    print ('V-measure:', metrics.v_measure_score(new_target, km.labels_))
    print ('Adjusted Rand Score:', metrics.adjusted_rand_score(new_target, km.labels_))
    print ('Adjusted Mutual Info Score:', metrics.adjusted_mutual_info_score(new_target, km.labels_))
    print ('The contingency matrix:\n',metrics.confusion_matrix(new_target, km.labels_),'\n'*2)

# %% [markdown]
# ## SVD

# %%
homo = []
complet = []
vmeasure = []
rands = []
mutual = []

# %%
valuee = [1,2,3,5,10,20,50,100,300]

# %%
for i in [1,2,3,5,10,20,50,100,300]:
    print('r =',i)
    
    svd = TruncatedSVD(n_components = i, n_iter = 13,random_state = 42)
    lsa = make_pipeline(svd)    
    X_reduced = lsa.fit_transform(X)    
    k_means(X_reduced, new_target)
    
    print('----------------------------------')
# Out:
# r = 1
# Homogeneity: 0.060815390048
# Completeness: 0.0618672085677
# V-measure: 0.061336790428
# Adjusted Rand Score: 0.081807139568
# Adjusted Mutual Info Score: 0.0607294069086
# The contingency matrix:
#  [[2856 1123]
#  [1690 2213]]
#
#
# ----------------------------------
# r = 2
# Homogeneity: 0.416392568838
# Completeness: 0.45020508557
# V-measure: 0.432639186434
# Adjusted Rand Score: 0.435175333573
# Adjusted Mutual Info Score: 0.416339137867
# The contingency matrix:
#  [[  59 3920]
#  [2621 1282]]
#
#
# ----------------------------------
# r = 3
# Homogeneity: 0.409417997305
# Completeness: 0.444737889162
# V-measure: 0.426347693181
# Adjusted Rand Score: 0.424857126869
# Adjusted Mutual Info Score: 0.409363927693
# The contingency matrix:
#  [[3922   57]
#  [1315 2588]]
#
#
# ----------------------------------
# r = 5
# Homogeneity: 0.403740610021
# Completeness: 0.44842034028
# V-measure: 0.424909171599
# Adjusted Rand Score: 0.396880592755
# Adjusted Mutual Info Score: 0.403686020144
# The contingency matrix:
#  [[  24 3955]
#  [2469 1434]]
#
#
# ----------------------------------
# r = 10
# Homogeneity: 0.420719074534
# Completeness: 0.456951854893
# V-measure: 0.43808756802
# Adjusted Rand Score: 0.433168688104
# Adjusted Mutual Info Score: 0.420666039574
# The contingency matrix:
#  [[3934   45]
#  [1302 2601]]
#
#
# ----------------------------------
# r = 20
# Homogeneity: 0.42265665009
# Completeness: 0.460252301346
# V-measure: 0.440654034749
# Adjusted Rand Score: 0.4314999974
# Adjusted Mutual Info Score: 0.422603792467
# The contingency matrix:
#  [[3941   38]
#  [1314 2589]]
#
#
# ----------------------------------
# r = 50
# Homogeneity: 0.412652401004
# Completeness: 0.453209487259
# V-measure: 0.431981094469
# Adjusted Rand Score: 0.414989764456
# Adjusted Mutual Info Score: 0.412598627279
# The contingency matrix:
#  [[  33 3946]
#  [2534 1369]]
#
#
# ----------------------------------
# r = 100
# Homogeneity: 0.414875661704
# Completeness: 0.455318817983
# V-measure: 0.434157421833
# Adjusted Rand Score: 0.417281825271
# Adjusted Mutual Info Score: 0.414822091541
# The contingency matrix:
#  [[  32 3947]
#  [2540 1363]]
#
#
# ----------------------------------
# r = 300
# Homogeneity: 0.407349425633
# Completeness: 0.449924720544
# V-measure: 0.427579852511
# Adjusted Rand Score: 0.405238185889
# Adjusted Mutual Info Score: 0.407295166278
# The contingency matrix:
#  [[  29 3950]
#  [2500 1403]]
#
#
# ----------------------------------

# %%
plt.plot(valuee, homo,valuee, complet,valuee, vmeasure,valuee, rands,valuee, mutual)
plt.xlabel('r', fontsize = 20)
plt.legend(('Homogeneity', 'Completeness', 'V-measure', 'Adjusted Rand Score','Adjusted Mutual Info Score'))
plt.show()

# %% [markdown]
# ## NMF

# %%
homo = []
complet = []
vmeasure = []
rands = []
mutual = []

# %%
for i in [1,2,3,5,10,20,50,100,300]:
    print('r =',i)
    
    nmf = NMF(n_components = i, random_state = 42)
    lsa = make_pipeline(nmf)
    X_reduced = lsa.fit_transform(X)
    k_means(X_reduced, new_target)
    
    print('----------------------------------')
# Out:
# r = 1
# Homogeneity: 0.060815390048
# Completeness: 0.0618672085677
# V-measure: 0.061336790428
# Adjusted Rand Score: 0.081807139568
# Adjusted Mutual Info Score: 0.0607294069086
# The contingency matrix:
#  [[1123 2856]
#  [2213 1690]]
#
#
# ----------------------------------
# r = 2
# Homogeneity: 0.447171906097
# Completeness: 0.451990582919
# V-measure: 0.44956833269
# Adjusted Rand Score: 0.535092339226
# Adjusted Mutual Info Score: 0.447121294338
# The contingency matrix:
#  [[3191  788]
#  [ 270 3633]]
#
#
# ----------------------------------
# r = 3
# Homogeneity: 0.445920027635
# Completeness: 0.447751042867
# V-measure: 0.446833659496
# Adjusted Rand Score: 0.543665999817
# Adjusted Mutual Info Score: 0.445869301384
# The contingency matrix:
#  [[3293  686]
#  [ 349 3554]]
#
#
# ----------------------------------
# r = 5
# Homogeneity: 0.353168533948
# Completeness: 0.386314201566
# V-measure: 0.368998527371
# Adjusted Rand Score: 0.374190087787
# Adjusted Mutual Info Score: 0.353109314362
# The contingency matrix:
#  [[3868  111]
#  [1419 2484]]
#
#
# ----------------------------------
# r = 10
# Homogeneity: 0.409961278661
# Completeness: 0.436468895856
# V-measure: 0.422800018308
# Adjusted Rand Score: 0.44697343545
# Adjusted Mutual Info Score: 0.409907259209
# The contingency matrix:
#  [[3875  104]
#  [1202 2701]]
#
#
# ----------------------------------
# r = 20
# Homogeneity: 0.451762081327
# Completeness: 0.471921973283
# V-measure: 0.461622027164
# Adjusted Rand Score: 0.504719371629
# Adjusted Mutual Info Score: 0.451711889197
# The contingency matrix:
#  [[3867  112]
#  [1029 2874]]
#
#
# ----------------------------------
# r = 50
# Homogeneity: 0.0653130568904
# Completeness: 0.169764199877
# V-measure: 0.094333403384
# Adjusted Rand Score: 0.0226173958206
# Adjusted Mutual Info Score: 0.0652274294628
# The contingency matrix:
#  [[3961   18]
#  [3329  574]]
#
#
# ----------------------------------
# r = 100
# Homogeneity: 0.00225591849559
# Completeness: 0.0966940958436
# V-measure: 0.00440897357488
# Adjusted Rand Score: -6.75336052934e-05
# Adjusted Mutual Info Score: 0.00216183011727
# The contingency matrix:
#  [[3961   18]
#  [3903    0]]
#
#
# ----------------------------------
# r = 300
# Homogeneity: 0.00165995977982
# Completeness: 0.0207215140694
# V-measure: 0.00307369212267
# Adjusted Rand Score: 0.000258297391681
# Adjusted Mutual Info Score: 0.00156798264081
# The contingency matrix:
#  [[3958   21]
#  [3846   57]]
#
#
# ----------------------------------

# %%
plt.plot(valuee, homo,valuee, complet,valuee, vmeasure,valuee, rands,valuee, mutual)
plt.xlabel('r', fontsize = 20)
plt.legend(('Homogeneity', 'Completeness', 'V-measure', 'Adjusted Rand Score','Adjusted Mutual Info Score'))
plt.show()

# %% [markdown]
# # problem 4

# %%
def plot_clusters(actual_labels, clustered_labels, X_2d):
    color = ["r", "b"]
    mark = ["o", "+"]
    for i in range(len(new_target)):
        plt.scatter(X_2d[i, 0], X_2d[i, 1], s=12, marker=mark[actual_labels[i]], color=color[clustered_labels[i]], alpha=0.5)
    plt.show()

# %% [markdown]
# ## SVD

# %%
svd = TruncatedSVD(n_components=10, n_iter=13, random_state=42)
lsa = make_pipeline(svd)
X_reduced = lsa.fit_transform(X)

km = KMeans(n_clusters=2, init='k-means++', max_iter=500, n_init=5)
km.fit(X_reduced)
clustered_labels = km.labels_

X_2d = svd.fit_transform(X)

plot_clusters(new_target, clustered_labels, X_2d)

print ('The contingency matrix:\n',metrics.confusion_matrix(new_target, km.labels_),'\n'*2)
# Out:
# The contingency matrix:
#  [[3934   45]
#  [1302 2601]]

# %% [markdown]
# ## nmf

# %%
nmf = NMF(n_components=2, random_state=42)
lsa = make_pipeline(nmf)
X_reduced = lsa.fit_transform(X)

km = KMeans(n_clusters=2, init='k-means++', max_iter=500, n_init=5)
km.fit(X_reduced)
clustered_labels = km.labels_

X_2d = nmf.fit_transform(X)

plot_clusters(new_target, clustered_labels, X_2d)

print ('The contingency matrix:\n',metrics.confusion_matrix(new_target, km.labels_),'\n'*2)
# Out:
# The contingency matrix:
#  [[ 788 3191]
#  [3633  270]]

# %% [markdown]
# ## normalized svd

# %%
svd = TruncatedSVD(n_components=10, n_iter=13, random_state=42)
normalizer = Normalizer(copy=False)
lsa = make_pipeline(svd, normalizer)

X_reduced = lsa.fit_transform(X)

km = KMeans(n_clusters=2, init='k-means++', max_iter=500, n_init=5)
km.fit(X_reduced)
clustered_labels = km.labels_

X_2d = svd.fit_transform(X)

plot_clusters(new_target, clustered_labels, X_2d)

print ('The contingency matrix:\n',metrics.confusion_matrix(new_target, km.labels_),'\n'*2)
# Out:
# The contingency matrix:
#  [[ 557 3422]
#  [3541  362]]

# %% [markdown]
# ## method applied on NMF

# %%
## non-linear NMF
nmf = NMF(n_components=2, random_state=42)
lsa = make_pipeline(nmf)
X_reduced = lsa.fit_transform(X)

for j in range(X_reduced.shape[0]):
    for k in range(X_reduced.shape[1]):
        if X_reduced[j][k] == 0:
            X_reduced[j][k] = -2
        else:
            X_reduced[j][k] = log(X_reduced[j][k], 10)

km = KMeans(n_clusters=2, init='k-means++', max_iter=500, n_init=5)
km.fit(X_reduced)
clustered_labels = km.labels_

X_2d = nmf.fit_transform(X)

plot_clusters(new_target, clustered_labels, X_2d)

print ('The contingency matrix:\n',metrics.confusion_matrix(new_target, km.labels_),'\n'*2)
# Out:
# The contingency matrix:
#  [[3462  517]
#  [ 387 3516]]

# %%
## normalizer NMF

nmf = NMF(n_components=2, random_state=42)
normalizer = Normalizer(copy=False)
lsa = make_pipeline(nmf, normalizer)
X_reduced = lsa.fit_transform(X)

km = KMeans(n_clusters=2, init='k-means++', max_iter=500, n_init=5)
km.fit(X_reduced)
clustered_labels = km.labels_

X_2d = nmf.fit_transform(X)

plot_clusters(new_target, clustered_labels, X_2d)

print ('The contingency matrix:\n',metrics.confusion_matrix(new_target, km.labels_),'\n'*2)
# Out:
# The contingency matrix:
#  [[ 373 3606]
#  [3386  517]]

# %%
##  use normalizer and  non-linear
nmf = NMF(n_components=2, random_state=42)
normalizer = Normalizer(copy=False)
lsa = make_pipeline(nmf, normalizer)
X_reduced = lsa.fit_transform(X)

for j in range(X_reduced.shape[0]):
    for k in range(X_reduced.shape[1]):
        if X_reduced[j][k] == 0:
            X_reduced[j][k] = -2
        else:
            X_reduced[j][k] = log(X_reduced[j][k], 10)
            
km = KMeans(n_clusters=2, init='k-means++', max_iter=500, n_init=5)
km.fit(X_reduced)
clustered_labels = km.labels_

X_2d = nmf.fit_transform(X)

plot_clusters(new_target, clustered_labels, X_2d)

print ('The contingency matrix:\n',metrics.confusion_matrix(new_target, km.labels_),'\n'*2)
# Out:
# The contingency matrix:
#  [[1185 2794]
#  [3733  170]]

# %% [markdown]
# # question 5

# %%
comp_tech_subclasses = ['comp.graphics',
                        'comp.os.ms-windows.misc',
                        'comp.sys.ibm.pc.hardware',
                        'comp.sys.mac.hardware',
                        'comp.windows.x']

rec_act_subclasses = ['rec.autos',
                      'rec.motorcycles',
                      'rec.sport.baseball',
                      'rec.sport.hockey']

science_subclass = ['sci.crypt', 'sci.electronics', 'sci.med', 'sci.space']

miscellaneous_subclass = ['misc.forsale']

politics_subclass = ['talk.politics.misc', 'talk.politics.guns', 'talk.politics.mideast']

religion_subclass = ['talk.religion.misc', 'alt.atheism', 'soc.religion.christian']

dataset = fetch_20newsgroups(subset='all',
                             categories=comp_tech_subclasses + rec_act_subclasses + science_subclass +
                                        miscellaneous_subclass + politics_subclass + religion_subclass,
                             shuffle=True,
                             random_state=42,
                             remove=('headers', 'footers', 'quotes'))

stop_words = text.ENGLISH_STOP_WORDS

vect_20 = CountVectorizer(analyzer = 'word', stop_words = stop_words, min_df = 3)
counts_20 = vect_20.fit_transform(dataset.data)
TFxIDF_transformer = TfidfTransformer()
X_20 = TFxIDF_transformer.fit_transform(counts_20)

print("The dimension of TF-IDF Vector with min_df=3 is",X_20.shape)
# Out:
# The dimension of TF-IDF Vector with min_df=3 is (18846, 35684)

# %%
for i in [1,2,3,5,10,20,50,100,300]:
    
    print('r =',i)
    
    svd = TruncatedSVD(n_components = i, n_iter = 13,random_state = 42)
    lsa = make_pipeline(svd)    
    X_reduced = lsa.fit_transform(X_20)    
    km = KMeans(n_clusters=20, init='k-means++', max_iter=500, n_init=5)
    km.fit(X_reduced)
    print ('Homogeneity:', metrics.homogeneity_score(dataset.target, km.labels_))
    print ('Completeness:', metrics.completeness_score(dataset.target, km.labels_))
    print ('V-measure:', metrics.v_measure_score(dataset.target, km.labels_))
    print ('Adjusted Rand Score:', metrics.adjusted_rand_score(dataset.target, km.labels_))
    print ('Adjusted Mutual Info Score:', metrics.adjusted_mutual_info_score(dataset.target, km.labels_))
    print ('The contingency matrix:\n',metrics.confusion_matrix(dataset.target, km.labels_),'\n'*2)
    print('----------------------------------')
# Out:
# r = 1
# Homogeneity: 0.0148174719183
# Completeness: 0.0160664895418
# V-measure: 0.0154167241737
# Adjusted Rand Score: 0.00291339293123
# Adjusted Mutual Info Score: 0.0116118368245
# The contingency matrix:
#  [[ 51  47  22  36  62  62  11  35  34  54  72  83  21  56   9   0  52  45
#    25  22]
#  [ 85  67  12  47  70  71   3  28  28 109  97  93  12 105   5   0  53  44
#    23  21]
#  [ 70  82  13  36  57  93   1  53  54 100  61  72  24  97   5   0  35  73
#    39  20]
#  [ 81  89  11  24  61  85   0  21  58  93  82  93  24 104   4   0  30  79
#    27  16]
#  [ 85  61   6  42  75  84   3  40  38  90  68  90  10  91   2   0  59  58
#    38  23]
#  [106  47   6  48  81  83   5  22  22 106 111 112  10  83   5   0  65  34
#    15  27]
#  [110  33   4  65 106  56   1  21  18  94 122  99   5  77   0   0  83  27
#    11  43]
#  [ 96  52   5  55  97  79   1  68  22  85  87 102   8  71   2   0  72  30
#    13  45]
#  [ 99  40   3  77  97  51   0  46  15  80 112  94   8  66   0   0 103  29
#    17  59]
#  [ 96  44  10  77  93  70   0  66  28  70  99  90  12  58   1   0  88  28
# Homogeneity: 0.226222987058
# Completeness: 0.340005841557
# V-measure: 0.271682165256
# Adjusted Rand Score: 0.0423955517223
# Adjusted Mutual Info Score: 0.223659808303
# The contingency matrix:
#  [[ 26   0   9   0 287   0   0   2   2   0   0 103  42   2   0   6   4 314
#     0   2]
#  [ 17 193 213   0 438   0  58   0   0   0   3   0   0   2   3   0   1  45
#     0   0]
#  [ 12 452  84  20 287   0  74   0   1   0   1   1   0   1  19   0   0  33
#     0   0]
#  [ 14  63 125 189 306   0 185   0   0   0   1   0   0   4  75   0   0  14
#     4   2]
#  [  9  16 148 107 474   0 115   0   3   0   1   0   0   1  56   0   0  32
#     1   0]
#  [ 20 322 139   1 449   0   9   0   0   0   5   0   0  12   4   0   0  27
#     0   0]
#  [ 10  21  83  60 568   0  47   0   0   0  65   0   0   0  49   0   0  19
#    23  30]
#  [ 14   1  44   3 531   0   0   0   2   0   2   0   0   1   0   1   0  79
#     0 312]
#  [ 34   0  42  13 719   0   0   0   2   0   0   3   0   0   0   0   0 147
#     2  34]
#  [ 11   1  46   0 476   0   0   0   0   0   2   1   0   1   0   1   0  70
#   384   1]
#  [  9   0  22   0 305   0   0   0   1   0   7   0   0   0   0   0   0  45
#   609   1]
#  [ 14  16  23   0 372   0   2   0   1   0   1   0   0 340  11   9   1 200
#     0   1]
#  [ 24  18 128  13 693   0  14   0   0   0   1   1   0   6  13   0   0  52
#     2  19]
#  [ 10   1  76   0 579   0   0   0   1  71   0   4   0   0   1   0   0 247
#     0   0]
#  [ 27   9  39   0 720   0   0   0   3   0   1   0   0   0   0   0   0 185
#     2   1]
#  [ 15   1  27   0 295   0   0   2   0   0   0 360   7   0   0   4   1 285
#     0   0]
#  [ 15   1   6   0 341   0   1   2   1   0   3   3   0   0   0 178   0 354
#     1   4]
#  [  6   0   4   0 270 135   0 270   1   0   2   6  61   0   0   2  41 142
#     0   0]
#  [  7   0   7   1 313   0   0   1   1   0   0   1   0   0   0  58   0 382
#     2   2]
#  [ 15   1   7   0 251   0   0   1   2   2   0 104   3   0   0  48   8 182
#     2   2]]
#
#
# ----------------------------------

# %%
for i in [1,2,3,5,10,15,20,35,50]:
    
    print('r =',i)
    
    nmf = NMF(n_components = i, random_state = 42)
    lsa = make_pipeline(nmf)
    X_reduced = lsa.fit_transform(X_20)  
    km = KMeans(n_clusters=20, init='k-means++', max_iter=500, n_init=5)
    km.fit(X_reduced)

    print ('Homogeneity:', metrics.homogeneity_score(dataset.target, km.labels_))
    print ('Completeness:', metrics.completeness_score(dataset.target, km.labels_))
    print ('V-measure:', metrics.v_measure_score(dataset.target, km.labels_))
    print ('Adjusted Rand Score:', metrics.adjusted_rand_score(dataset.target, km.labels_))
    print ('Adjusted Mutual Info Score:', metrics.adjusted_mutual_info_score(dataset.target, km.labels_))
    print ('The contingency matrix:\n',metrics.confusion_matrix(dataset.target, km.labels_),'\n'*2)
    print('----------------------------------')
# Out:
# r = 1
# Homogeneity: 0.0155234553997
# Completeness: 0.0167085298875
# V-measure: 0.0160942068068
# Adjusted Rand Score: 0.00317354884099
# Adjusted Mutual Info Score: 0.0123257284147
#  [198   2  25   0 226   0   0  19   0   0   0  10  22  53   1   4   0   0
#   439   0]
#  [183   2  29 224   0   0  12   2   4   0  12   7   8  62 290  58  97   0
#     1   0]
#  [389   1 153   5   0   0   0   4   2   2  19  40 114 144  80   4   0   0
#     5  22]
#  [417   3 111   0   0  71   1   2   1   0   1  19  34 293   2  32   0   3
#     0   0]
#  [445   3  53   0   0   0   3  12   0   0   6  13 128 268  12  39   0   0
#     5   0]
#  [212 408  36   0   0   0   3   0   1   0   0   8  11  86   0  68   0 163
#     0   1]
#  [238   8  18   0   0   0 103   3   1   0   0   0  10 126   8 392   0   1
#     2   0]
#  [175   8  14   0   0   0 303   1   0   0   0   1   4  51   3 377   0   2
#     1   0]
#  [224   4  10   0   0   0  53   0   0   0   1   5  25 126   1 318   0   0
#     6   2]
#  [220 122  14   0   0   2  15   0   0   0   1   1   3  91   3  97   0  55
#     4   0]]
#
#
# ----------------------------------
# r = 15
# Homogeneity: 0.251334613736
# Completeness: 0.318221028043
# V-measure: 0.280850379836
# Adjusted Rand Score: 0.0588835691248
# Adjusted Mutual Info Score: 0.248885294714
# The contingency matrix:
#  [[ 30 281  40   0   1   2 120   0   0   3   1   0   2   2   0 301   0   0
#     6  10]
#  [ 77  70   0  31   0   3   0  29   0   2  43   0  18   0   1 246   0  65
#   264 124]
#  [ 39  52   0  51   0   1   1 290   0   0  71  17  11   0   1 230   6  51
#   100  64]
#  [ 50  37   0  97   3   4   0  37   0  11  19 175  23   0   1 197   0 210
#    22  96]
#  [ 76  63   0  55   1   1   0   5   0   6  21  99  17   0   1 280   0 239
#    11  88]
#  [ 46  26   0   4   0   7   0  43   0   1 385   0  12   0   2 205  74  13
#    81  89]
#  [ 14  24   0  26  16   0   1  12   0  55   2  49 333  15  44 229   0  78
#     6  71]
#  [ 30  70   6   0   0   1   0   0   0 366   6   3   6 153   1 310   0   0
#     3  35]
#  [ 34 135   2   0   2   0   3   1   0 298   3  12  14  43   0 412   0   2
#     3  32]
#  [ 38 110   1   0 333   1   1   0   0   3   2   0  26   0   2 431   0   0
#     3  43]
#  [ 15  65   0   0 534   0   0   0   0   2   0   0  44   1  10 308   0   1
#     0  19]
#  [ 35 149  35   0   0 341   0   5   0   3   2   0   4   0   1 357   0  11
#    25  23]
#  [ 77 105   0   4   2   5   1   3   0  53   5  12  29   7   0 535   0  42
#    20  84]
#  [ 63 286   3   0   0   0   4   0  71   4   1   0  13   0   0 478   0   0
#    12  55]
#  [ 33 260   9   0   1   0   0   0   0  18   1   0  28   0   1 535   0   1
#    68  32]
#  [ 33 192  24   0   0   0 401   1   0   1   0   0   4   0   0 319   0   0
#     0  22]
#  [ 24 190 279   0   2   1   4   0   0   9   1   0   9   1   1 371   0   6
#     1  11]
#  [ 23  98 535   0   0   0   5   0   0   6   0   0   4   0   0 262   0   1
#     0   6]
#  [ 19 221 157   0   1   0   1   1   0   9   0   1   9   1   0 344   0   1
#     2   8]
#  [ 22 176  41   0   3   0 112   0   2   1   0   0   1   1   0 259   0   0
#     3   7]]
#
#
# ----------------------------------
# r = 20
# Homogeneity: 0.216863563282
# Completeness: 0.285411105186
